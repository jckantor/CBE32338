# %% [markdown]
# <!--NOTEBOOK_HEADER-->
# *This notebook contains material from [CBE32338](https://jckantor.github.io/CBE32338);
# content is available [on Github](https://github.com/jckantor/CBE32338.git).*

# %% [markdown]
# <!--NAVIGATION-->
# < [2.11 Model Identification: Fitting models to data](https://jckantor.github.io/CBE32338/02.11-TCLab-Lab-2-Fitting.html) | [Contents](toc.html) | [3.1 Open and Closed Loop Estimation](https://jckantor.github.io/CBE32338/03.01-Open-and-Closed-Loop-Estimation.html) ><p><a href="https://colab.research.google.com/github/jckantor/CBE32338/blob/master/docs/03.00-State-Estimation.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://jckantor.github.io/CBE32338/03.00-State-Estimation.ipynb"> <img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>

# %% [markdown]
# # 3.0 State Estimation
#
#
# ## Reference materials
#
# * Wang, Shuo. "Kalman Filter in a Nutshell." *Towards Data Science*, https://towardsdatascience.com/kalman-filter-in-a-nutshell-e66154a06862. Accessed 6 December 2020.

# %% [markdown]
# <!--NAVIGATION-->
# < [2.11 Model Identification: Fitting models to data](https://jckantor.github.io/CBE32338/02.11-TCLab-Lab-2-Fitting.html) | [Contents](toc.html) | [3.1 Open and Closed Loop Estimation](https://jckantor.github.io/CBE32338/03.01-Open-and-Closed-Loop-Estimation.html) ><p><a href="https://colab.research.google.com/github/jckantor/CBE32338/blob/master/docs/03.00-State-Estimation.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://jckantor.github.io/CBE32338/03.00-State-Estimation.ipynb"> <img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>
